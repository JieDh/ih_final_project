# %% [markdown]
# ### IMPORT MODULES

# %%
import sqlalchemy
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import requests
import re

# %% [markdown]
# # API WORK

# %% [markdown]
# ## Connecting to API (related job)

# %%
response = requests.get('http://ddragon.leagueoflegends.com/cdn/11.5.1/data/es_ES/champion.json')

# %% [markdown]
# ## Getting json

# %%
champ_ls = list(response.json()['data'].keys())

# %%
champ_df = pd.DataFrame()
for i in range(len(champ_ls)):
    champ_data = pd.json_normalize(response.json()['data'][champ_ls[i]])
    champ_df = champ_df.append(champ_data)

# %%
champ_df
# Out:
#    version       id  key     name                          title  \
# 0   11.5.1   Aatrox  266   Aatrox       la Espada de los Oscuros
# 0   11.5.1     Ahri  103     Ahri  La Mujer Zorro de nueve Colas
# 0   11.5.1    Akali   84    Akali            la Asesina Sigilosa
# 0   11.5.1  Alistar   12  Alistar                   El Minotauro
# 0   11.5.1    Amumu   32    Amumu                La Momia Triste
# ..     ...      ...  ...      ...                            ...
# 0   11.5.1      Zed  238      Zed      El Maestro de las Sombras
# 0   11.5.1    Ziggs  115    Ziggs      El Experto en Hexplosivos
# 0   11.5.1   Zilean   26   Zilean         El Guardián del Tiempo
# 0   11.5.1      Zoe  142      Zoe      el Aspecto del Crepúsculo
# 0   11.5.1     Zyra  143     Zyra             La Dama de Espinas
#
#                                                 blurb              tags  \
# 0   Aatrox y sus hermanos, otrora respetados defen...   [Fighter, Tank]
# 0   Ahri es una vastaya conectada de forma innata ...  [Mage, Assassin]
# 0   Tras abandonar la orden de los Kinkou y su tít...        [Assassin]
# 0   Alistar, un poderoso guerrero con una reputaci...   [Tank, Support]
# 0   Cuenta la leyenda que Amumu es un alma solitar...      [Tank, Mage]
# ..                                                ...               ...
# 0   Zed, despiadado y nada compasivo, es el líder ...        [Assassin]
# 0   Gran amante de las bombas grandes y las mechas...            [Mage]
# 0   Zilean, el que un día fuera un poderoso mago d...   [Support, Mage]
# 0   Como personificación de la travesura, de la im...   [Mage, Support]
# 0   Nacida gracias a un fenómeno sobrenatural hace...   [Mage, Support]
#
#             partype  info.attack  info.defense  ...  stats.hpregen  \
# 0   Pozo sangriento            8             4  ...            3.0
# 0              Maná            3             4  ...            5.5
# 0           Energía            5             3  ...            8.0
# 0              Maná            6             9  ...            8.5
# 0              Maná            2             6  ...            9.0
# ..              ...          ...           ...  ...            ...
# 0           Energía            9             2  ...            7.0
# 0              Maná            2             4  ...            6.5
# 0              Maná            2             5  ...            5.5
# 0              Maná            1             7  ...            6.5
# 0              Maná            4             3  ...            5.5
#
#     stats.hpregenperlevel stats.mpregen stats.mpregenperlevel stats.crit  \
# 0                    1.00          0.00                  0.00          0
# 0                    0.60          8.00                  0.80          0
# 0                    0.50         50.00                  0.00          0
# 0                    0.85          8.50                  0.80          0
# 0                    0.85          7.38                  0.53          0
# ..                    ...           ...                   ...        ...
# 0                    0.65         50.00                  0.00          0
# 0                    0.60          8.00                  0.80          0
# 0                    0.50         11.34                  0.80          0
# 0                    0.60          8.00                  0.65          0
# 0                    0.50         13.00                  0.40          0
#
#     stats.critperlevel  stats.attackdamage  stats.attackdamageperlevel  \
# 0                    0                60.0                        5.00
# 0                    0                53.0                        3.00
# 0                    0                62.0                        3.30
# 0                    0                62.0                        3.75
# 0                    0                53.0                        3.80
# ..                 ...                 ...                         ...
# 0                    0                63.0                        3.40
# 0                    0                54.0                        3.10
# 0                    0                52.0                        3.00
# 0                    0                58.0                        3.30
# 0                    0                53.0                        3.20
#
#     stats.attackspeedperlevel  stats.attackspeed
# 0                       2.500              0.651
# 0                       2.000              0.668
# 0                       3.200              0.625
# 0                       2.125              0.625
# 0                       2.180              0.736
# ..                        ...                ...
# 0                       3.300              0.651
# 0                       2.000              0.656
# 0                       2.130              0.625
# 0                       2.500              0.625
# 0                       2.110              0.625
#
# [154 rows x 39 columns]

# %%
item_req = requests.get('http://ddragon.leagueoflegends.com/cdn/11.5.1/data/es_ES/item.json')

item_ls = []
for i in list(range(0,10000)):
    try:
        a = item_req.json()['data'][str(i)]
        item_ls.append(str(i))
    except:
        pass

# %%
item_table = pd.DataFrame()
for i in item_ls:
    item_id = i
    try:
        name = item_req.json()['data'][i]['name']
    except:
        name = np.nan
        
    try:
        upper_item = item_req.json()['data'][i]['into']
    except:
        upper_item = np.nan
    
    try:
        explain = item_req.json()['data'][i]['plaintext']
    except:
        explain = np.nan
    
    try:
        buy_price = item_req.json()['data'][i]['gold']['base']
    except:
        buy_price = np.nan
    
    try:
        sell_price = item_req.json()['data'][i]['gold']['sell']
    except:
        sell_price = np.nan
        
    try:
        tag = item_req.json()['data'][i]['tags'][0]
    except:
        tag = np.nan
    
    pre_df = pd.DataFrame({'item_id' : [item_id],
                           'name' : [name],
                           'upper_item' : [upper_item],
                           'explain' : [explain],
                           'buy_price' : [buy_price],
                           'sell_price' : [sell_price],
                           'tag' : [tag]
                          })
    
    item_table = item_table.append(pre_df)

# %%
item_table
# Out:
#    item_id                       name  \
# 0     1001                      Botas
# 0     1004       Amuleto de las hadas
# 0     1006  Perla de rejuvenecimiento
# 0     1011        Cinturón de gigante
# 0     1018           Capa de agilidad
# ..     ...                        ...
# 0     6691     Filoscuro de Draktharr
# 0     6692                    Eclipse
# 0     6693        Garra de merodeador
# 0     6694          Rencor de Serylda
# 0     6695      Colmillo de serpiente
#
#                                            upper_item  \
# 0          [3158, 3006, 3009, 3020, 3047, 3111, 3117]
# 0                                        [3114, 4642]
# 0                                        [3109, 3801]
# 0                [3075, 3001, 3083, 3116, 3748, 4637]
# 0   [3124, 6676, 3086, 3031, 3036, 3072, 3095, 313...
# ..                                                ...
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
#
#                                           explain  buy_price  sell_price  \
# 0   Aumenta levemente la velocidad de movimiento.        300         210
# 0      Aumenta levemente la regeneración de maná.        250         175
# 0      Aumenta levemente la regeneración de vida.        150         105
# 0                 Aumenta en gran medida la vida.        500         630
# 0   Aumenta levemente la probabilidad de crítico.        600         420
# ..                                            ...        ...         ...
# 0                                                       1000        2240
# 0                                                        850        2240
# 0                                                       1000        2240
# 0                                                        850        2380
# 0                                                        625        1820
#
#                tag
# 0            Boots
# 0        ManaRegen
# 0      HealthRegen
# 0           Health
# 0   CriticalStrike
# ..             ...
# 0           Damage
# 0           Damage
# 0           Damage
# 0           Damage
# 0           Damage
#
# [199 rows x 7 columns]
