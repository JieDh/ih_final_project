# %%
import pandas as pd
import re

# %%
s1 = pd.read_csv('clean_data/cleansers.csv')
s2 = pd.read_csv('clean_data/creams.csv')
s3 = pd.read_csv('clean_data/essence.csv')
s4 = pd.read_csv('clean_data/eyecreams.csv')
s5 = pd.read_csv('clean_data/masks.csv')
s6 = pd.read_csv('clean_data/scrubs.csv')
s7 = pd.read_csv('clean_data/sunscreens.csv')
s8 = pd.read_csv('clean_data/toner.csv')

# %%
df = pd.concat([s1, s2, s3, s4, s5, s6, s7, s8], ignore_index=True)

# %%
df
# Out:
#       Unnamed: 0  Unnamed: 0.1  \
# 0              0             0
# 1              1             1
# 2              2             2
# 3              3             3
# 4              4             4
# ...          ...           ...
# 4381         760           786
# 4382         761           787
# 4383         762           787
# 4384         763           788
# 4385         764           789
#
#                                                    name  \
# 0      iUNIK - Calendula Complete Cleansing Oil - 200ml
# 1          Krave - Matcha Hemp Hydrating Cleanser 120ml
# 2      COSRX - Low pH Good Morning Gel Cleanser - 150ml
# 3                              heimish - All Clean Balm
# 4     SOME BY MI - AHA-BHA-PHA 30days Miracle Acne C...
# ...                                                 ...
# 4381    NATURE REPUBLIC - Pore Away Clear Toner - 300ml
# 4382          The Saem - Eco Energy Fresh Toner - 150ml
# 4383          The Saem - Eco Energy Fresh Toner - 150ml
# 4384       NEOGEN Dermalogy - Pore Refine Toner - 150ml
# 4385                   VANT 36.5 - AHA 5% Toner - 100ml
#
#                                                 details  \
# 0     Product Type: Cleansing Oil\n\n\nSkin Concern:...
# 1     Product Type: Cleansing Gel\n\n\nSkin Concern:...
# 2     Cruelty Free: Yes\n\n\nProduct Type: Cleansing...
# 3     Cruelty Free: Yes\n\n\nProduct Type: Cleansing...
# 4     Product Type: Cleansing Water\n\n\nSkin Concer...
# ...                                                 ...
# 4381  Usage: Day, Night\n\n\nProduct Type: Toner & M...
# 4382  Usage: Day, Night\n\n\nProduct Type: Toner & M...
# 4383  Usage: Day, Night\n\n\nProduct Type: Toner & M...
# 4384  Cruelty Free: Yes\n\n\nUsage: Day, Night\n\n\n...
# 4385  Usage: Day, Night\n\n\nProduct Type: Toner & M...
#
#                                             ingredients   price   best-seller  \
# 0                                                   NaN  15.19€  Best Sellers
# 1                                                   NaN  31.29€  Best Sellers
# 2     Water, Cocamidopropyl Betaine, Sodium Lauroyl ...   9.49€  Best Sellers
# 3     Ethylhexyl Palmitate, Cetyl Ethylhexanoate, PE...  14.89€  Best Sellers
# 4                                                   NaN  15.09€  Best Sellers
# ...                                                 ...     ...           ...
# 4381                                                NaN     NaN            no
# 4382                                                NaN     NaN            no
# 4383                                                NaN     NaN            no
# 4384                                                NaN  18.79€  Cruelty Free
# 4385                                                NaN     NaN            no
#
#            Step
# 0     cleansers
# 1     cleansers
# 2     cleansers
# 3     cleansers
# 4     cleansers
# ...         ...
# 4381      toner
# 4382      toner
# 4383      toner
# 4384      toner
# 4385      toner
#
# [4386 rows x 8 columns]

# %% [markdown]
# # 1. Separar marca y producto

# %%
df['name'] = df['name'].apply(lambda x: x.split(' - '))

# %%
df['brand'] = df['name'].apply(lambda x: x[0])
df['product name'] = df['name'].apply(lambda x: x[1:])

# %%
df
#el nombre del producto contiene más info de la necesaria, corregir
# Out:
#       Unnamed: 0  Unnamed: 0.1  \
# 0              0             0
# 1              1             1
# 2              2             2
# 3              3             3
# 4              4             4
# ...          ...           ...
# 4381         760           786
# 4382         761           787
# 4383         762           787
# 4384         763           788
# 4385         764           789
#
#                                                    name  \
# 0      [iUNIK, Calendula Complete Cleansing Oil, 200ml]
# 1         [Krave, Matcha Hemp Hydrating Cleanser 120ml]
# 2      [COSRX, Low pH Good Morning Gel Cleanser, 150ml]
# 3                             [heimish, All Clean Balm]
# 4     [SOME BY MI, AHA-BHA-PHA 30days Miracle Acne C...
# ...                                                 ...
# 4381    [NATURE REPUBLIC, Pore Away Clear Toner, 300ml]
# 4382          [The Saem, Eco Energy Fresh Toner, 150ml]
# 4383          [The Saem, Eco Energy Fresh Toner, 150ml]
# 4384       [NEOGEN Dermalogy, Pore Refine Toner, 150ml]
# 4385                   [VANT 36.5, AHA 5% Toner, 100ml]
#
#                                                 details  \
# 0     Product Type: Cleansing Oil\n\n\nSkin Concern:...
# 1     Product Type: Cleansing Gel\n\n\nSkin Concern:...
# 2     Cruelty Free: Yes\n\n\nProduct Type: Cleansing...
# 3     Cruelty Free: Yes\n\n\nProduct Type: Cleansing...
# 4     Product Type: Cleansing Water\n\n\nSkin Concer...
# ...                                                 ...
# 4381  Usage: Day, Night\n\n\nProduct Type: Toner & M...
# 4382  Usage: Day, Night\n\n\nProduct Type: Toner & M...
# 4383  Usage: Day, Night\n\n\nProduct Type: Toner & M...
# 4384  Cruelty Free: Yes\n\n\nUsage: Day, Night\n\n\n...
# 4385  Usage: Day, Night\n\n\nProduct Type: Toner & M...
#
#                                             ingredients   price   best-seller  \
# 0                                                   NaN  15.19€  Best Sellers
# 1                                                   NaN  31.29€  Best Sellers
# 2     Water, Cocamidopropyl Betaine, Sodium Lauroyl ...   9.49€  Best Sellers
# 3     Ethylhexyl Palmitate, Cetyl Ethylhexanoate, PE...  14.89€  Best Sellers
# 4                                                   NaN  15.09€  Best Sellers
# ...                                                 ...     ...           ...
# 4381                                                NaN     NaN            no
# 4382                                                NaN     NaN            no
# 4383                                                NaN     NaN            no
# 4384                                                NaN  18.79€  Cruelty Free
# 4385                                                NaN     NaN            no
#
#            Step             brand  \
# 0     cleansers             iUNIK
# 1     cleansers             Krave
# 2     cleansers             COSRX
# 3     cleansers           heimish
# 4     cleansers        SOME BY MI
# ...         ...               ...
# 4381      toner   NATURE REPUBLIC
# 4382      toner          The Saem
# 4383      toner          The Saem
# 4384      toner  NEOGEN Dermalogy
# 4385      toner         VANT 36.5
#
#                                            product name
# 0             [Calendula Complete Cleansing Oil, 200ml]
# 1                [Matcha Hemp Hydrating Cleanser 120ml]
# 2             [Low pH Good Morning Gel Cleanser, 150ml]
# 3                                      [All Clean Balm]
# 4     [AHA-BHA-PHA 30days Miracle Acne Clear Body Cl...
# ...                                                 ...
# 4381                     [Pore Away Clear Toner, 300ml]
# 4382                    [Eco Energy Fresh Toner, 150ml]
# 4383                    [Eco Energy Fresh Toner, 150ml]
# 4384                         [Pore Refine Toner, 150ml]
# 4385                              [AHA 5% Toner, 100ml]
#
# [4386 rows x 10 columns]

# %% [markdown]
# # 2. Separar producto y tamaño

# %%
product = []
for i in df['product name']:
    try:
        product.append(i[0])
    except:
        product.append(i)
print(len(product))
# Out:
# 4386

# %%
df['product'] = product

# %%
df
# Out:
#       Unnamed: 0  Unnamed: 0.1  \
# 0              0             0
# 1              1             1
# 2              2             2
# 3              3             3
# 4              4             4
# ...          ...           ...
# 4381         760           786
# 4382         761           787
# 4383         762           787
# 4384         763           788
# 4385         764           789
#
#                                                    name  \
# 0      [iUNIK, Calendula Complete Cleansing Oil, 200ml]
# 1         [Krave, Matcha Hemp Hydrating Cleanser 120ml]
# 2      [COSRX, Low pH Good Morning Gel Cleanser, 150ml]
# 3                             [heimish, All Clean Balm]
# 4     [SOME BY MI, AHA-BHA-PHA 30days Miracle Acne C...
# ...                                                 ...
# 4381    [NATURE REPUBLIC, Pore Away Clear Toner, 300ml]
# 4382          [The Saem, Eco Energy Fresh Toner, 150ml]
# 4383          [The Saem, Eco Energy Fresh Toner, 150ml]
# 4384       [NEOGEN Dermalogy, Pore Refine Toner, 150ml]
# 4385                   [VANT 36.5, AHA 5% Toner, 100ml]
#
#                                                 details  \
# 0     Product Type: Cleansing Oil\n\n\nSkin Concern:...
# 1     Product Type: Cleansing Gel\n\n\nSkin Concern:...
# 2     Cruelty Free: Yes\n\n\nProduct Type: Cleansing...
# 3     Cruelty Free: Yes\n\n\nProduct Type: Cleansing...
# 4     Product Type: Cleansing Water\n\n\nSkin Concer...
# ...                                                 ...
# 4381  Usage: Day, Night\n\n\nProduct Type: Toner & M...
# 4382  Usage: Day, Night\n\n\nProduct Type: Toner & M...
# 4383  Usage: Day, Night\n\n\nProduct Type: Toner & M...
# 4384  Cruelty Free: Yes\n\n\nUsage: Day, Night\n\n\n...
# 4385  Usage: Day, Night\n\n\nProduct Type: Toner & M...
#
#                                             ingredients   price   best-seller  \
# 0                                                   NaN  15.19€  Best Sellers
# 1                                                   NaN  31.29€  Best Sellers
# 2     Water, Cocamidopropyl Betaine, Sodium Lauroyl ...   9.49€  Best Sellers
# 3     Ethylhexyl Palmitate, Cetyl Ethylhexanoate, PE...  14.89€  Best Sellers
# 4                                                   NaN  15.09€  Best Sellers
# ...                                                 ...     ...           ...
# 4381                                                NaN     NaN            no
# 4382                                                NaN     NaN            no
# 4383                                                NaN     NaN            no
# 4384                                                NaN  18.79€  Cruelty Free
# 4385                                                NaN     NaN            no
#
#            Step             brand  \
# 0     cleansers             iUNIK
# 1     cleansers             Krave
# 2     cleansers             COSRX
# 3     cleansers           heimish
# 4     cleansers        SOME BY MI
# ...         ...               ...
# 4381      toner   NATURE REPUBLIC
# 4382      toner          The Saem
# 4383      toner          The Saem
# 4384      toner  NEOGEN Dermalogy
# 4385      toner         VANT 36.5
#
#                                            product name  \
# 0             [Calendula Complete Cleansing Oil, 200ml]
# 1                [Matcha Hemp Hydrating Cleanser 120ml]
# 2             [Low pH Good Morning Gel Cleanser, 150ml]
# 3                                      [All Clean Balm]
# 4     [AHA-BHA-PHA 30days Miracle Acne Clear Body Cl...
# ...                                                 ...
# 4381                     [Pore Away Clear Toner, 300ml]
# 4382                    [Eco Energy Fresh Toner, 150ml]
# 4383                    [Eco Energy Fresh Toner, 150ml]
# 4384                         [Pore Refine Toner, 150ml]
# 4385                              [AHA 5% Toner, 100ml]
#
#                                                 product
# 0                      Calendula Complete Cleansing Oil
# 1                  Matcha Hemp Hydrating Cleanser 120ml
# 2                      Low pH Good Morning Gel Cleanser
# 3                                        All Clean Balm
# 4     AHA-BHA-PHA 30days Miracle Acne Clear Body Cle...
# ...                                                 ...
# 4381                              Pore Away Clear Toner
# 4382                             Eco Energy Fresh Toner
# 4383                             Eco Energy Fresh Toner
# 4384                                  Pore Refine Toner
# 4385                                       AHA 5% Toner
#
# [4386 rows x 11 columns]

# %% [markdown]
# # 3. Separar detalles

# %%
df['details'] = df['details'].astype(str)

# %%
df['details'] = df['details'].apply(lambda x: x.split('\n\n\n'))

# %%
df
# Out:
#       Unnamed: 0  Unnamed: 0.1  \
# 0              0             0
# 1              1             1
# 2              2             2
# 3              3             3
# 4              4             4
# ...          ...           ...
# 4381         760           786
# 4382         761           787
# 4383         762           787
# 4384         763           788
# 4385         764           789
#
#                                                    name  \
# 0      [iUNIK, Calendula Complete Cleansing Oil, 200ml]
# 1         [Krave, Matcha Hemp Hydrating Cleanser 120ml]
# 2      [COSRX, Low pH Good Morning Gel Cleanser, 150ml]
# 3                             [heimish, All Clean Balm]
# 4     [SOME BY MI, AHA-BHA-PHA 30days Miracle Acne C...
# ...                                                 ...
# 4381    [NATURE REPUBLIC, Pore Away Clear Toner, 300ml]
# 4382          [The Saem, Eco Energy Fresh Toner, 150ml]
# 4383          [The Saem, Eco Energy Fresh Toner, 150ml]
# 4384       [NEOGEN Dermalogy, Pore Refine Toner, 150ml]
# 4385                   [VANT 36.5, AHA 5% Toner, 100ml]
#
#                                                 details  \
# 0     [Product Type: Cleansing Oil, Skin Concern: Bl...
# 1     [Product Type: Cleansing Gel, Skin Concern: Ac...
# 2     [Cruelty Free: Yes, Product Type: Cleansing Ge...
# 3     [Cruelty Free: Yes, Product Type: Cleansing Ba...
# 4     [Product Type: Cleansing Water, Skin Concern: ...
# ...                                                 ...
# 4381  [Usage: Day, Night, Product Type: Toner & Mist...
# 4382  [Usage: Day, Night, Product Type: Toner & Mist...
# 4383  [Usage: Day, Night, Product Type: Toner & Mist...
# 4384  [Cruelty Free: Yes, Usage: Day, Night, Product...
# 4385  [Usage: Day, Night, Product Type: Toner & Mist...
#
#                                             ingredients   price   best-seller  \
# 0                                                   NaN  15.19€  Best Sellers
# 1                                                   NaN  31.29€  Best Sellers
# 2     Water, Cocamidopropyl Betaine, Sodium Lauroyl ...   9.49€  Best Sellers
# 3     Ethylhexyl Palmitate, Cetyl Ethylhexanoate, PE...  14.89€  Best Sellers
# 4                                                   NaN  15.09€  Best Sellers
# ...                                                 ...     ...           ...
# 4381                                                NaN     NaN            no
# 4382                                                NaN     NaN            no
# 4383                                                NaN     NaN            no
# 4384                                                NaN  18.79€  Cruelty Free
# 4385                                                NaN     NaN            no
#
#            Step             brand  \
# 0     cleansers             iUNIK
# 1     cleansers             Krave
# 2     cleansers             COSRX
# 3     cleansers           heimish
# 4     cleansers        SOME BY MI
# ...         ...               ...
# 4381      toner   NATURE REPUBLIC
# 4382      toner          The Saem
# 4383      toner          The Saem
# 4384      toner  NEOGEN Dermalogy
# 4385      toner         VANT 36.5
#
#                                            product name  \
# 0             [Calendula Complete Cleansing Oil, 200ml]
# 1                [Matcha Hemp Hydrating Cleanser 120ml]
# 2             [Low pH Good Morning Gel Cleanser, 150ml]
# 3                                      [All Clean Balm]
# 4     [AHA-BHA-PHA 30days Miracle Acne Clear Body Cl...
# ...                                                 ...
# 4381                     [Pore Away Clear Toner, 300ml]
# 4382                    [Eco Energy Fresh Toner, 150ml]
# 4383                    [Eco Energy Fresh Toner, 150ml]
# 4384                         [Pore Refine Toner, 150ml]
# 4385                              [AHA 5% Toner, 100ml]
#
#                                                 product
# 0                      Calendula Complete Cleansing Oil
# 1                  Matcha Hemp Hydrating Cleanser 120ml
# 2                      Low pH Good Morning Gel Cleanser
# 3                                        All Clean Balm
# 4     AHA-BHA-PHA 30days Miracle Acne Clear Body Cle...
# ...                                                 ...
# 4381                              Pore Away Clear Toner
# 4382                             Eco Energy Fresh Toner
# 4383                             Eco Energy Fresh Toner
# 4384                                  Pore Refine Toner
# 4385                                       AHA 5% Toner
#
# [4386 rows x 11 columns]

# %%
product_type = []
for x in df['details']:
    product_type.append(re.findall(r"(Product Type: [a-zA-Z].+?)'", str(x)))

# %%
pr_type = []
for x in product_type:
    if len(x) >= 1:
        for i in x:
            pr_type.append(i)
    else:
        pr_type.append(x)
df['pr_type'] = pr_type
df['pr_type'] = df['pr_type'].apply(lambda x: str(x).split(':'))

# %%
product = []
for i in df['pr_type']:
    try:
        product.append(i[1])
    except:
        product.append(i)
print(len(product))
# Out:
# 4386

# %%
df['product type'] = product

# %%
skin_type = []
for x in df['details']:
    skin_type.append(re.findall(r"(Skin Type: [a-zA-Z].+?)'", str(x)))
sk_type = []
for x in skin_type:
    if len(x) >= 1:
        for i in x:
            sk_type.append(i)
    else:
        sk_type.append(x)
df['sk_type'] = sk_type
df['sk_type'] = df['sk_type'].apply(lambda x: str(x).split(':'))
skin_t = []
for i in df['sk_type']:
    try:
        skin_t.append(i[1])
    except:
        skin_t.append(i)
print(len(skin_t))
# Out:
# 4386

# %%
df['skin type'] = skin_t

# %%
skin_concern = []
for x in df['details']:
    skin_concern.append(re.findall(r"(Skin Concern: [a-zA-Z].+?)'", str(x)))
sk_concern = []
for x in skin_concern:
    if len(x) >= 1:
        for i in x:
            sk_concern.append(i)
    else:
        sk_concern.append(x)
df['sk_concern'] = sk_concern
df['sk_concern'] = df['sk_concern'].apply(lambda x: str(x).split(':'))
skin_c = []
for i in df['sk_concern']:
    try:
        skin_c.append(i[1])
    except:
        skin_c.append(i)
print(len(skin_c))
df['skin concern'] = skin_c
# Out:
# 4386

# %%
df.head(5)
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             0
# 1           1             1
# 2           2             2
# 3           3             3
# 4           4             4
#
#                                                 name  \
# 0   [iUNIK, Calendula Complete Cleansing Oil, 200ml]
# 1      [Krave, Matcha Hemp Hydrating Cleanser 120ml]
# 2   [COSRX, Low pH Good Morning Gel Cleanser, 150ml]
# 3                          [heimish, All Clean Balm]
# 4  [SOME BY MI, AHA-BHA-PHA 30days Miracle Acne C...
#
#                                              details  \
# 0  [Product Type: Cleansing Oil, Skin Concern: Bl...
# 1  [Product Type: Cleansing Gel, Skin Concern: Ac...
# 2  [Cruelty Free: Yes, Product Type: Cleansing Ge...
# 3  [Cruelty Free: Yes, Product Type: Cleansing Ba...
# 4  [Product Type: Cleansing Water, Skin Concern: ...
#
#                                          ingredients   price   best-seller  \
# 0                                                NaN  15.19€  Best Sellers
# 1                                                NaN  31.29€  Best Sellers
# 2  Water, Cocamidopropyl Betaine, Sodium Lauroyl ...   9.49€  Best Sellers
# 3  Ethylhexyl Palmitate, Cetyl Ethylhexanoate, PE...  14.89€  Best Sellers
# 4                                                NaN  15.09€  Best Sellers
#
#         Step       brand                                       product name  \
# 0  cleansers       iUNIK          [Calendula Complete Cleansing Oil, 200ml]
# 1  cleansers       Krave             [Matcha Hemp Hydrating Cleanser 120ml]
# 2  cleansers       COSRX          [Low pH Good Morning Gel Cleanser, 150ml]
# 3  cleansers     heimish                                   [All Clean Balm]
# 4  cleansers  SOME BY MI  [AHA-BHA-PHA 30days Miracle Acne Clear Body Cl...
#
#                                              product  \
# 0                   Calendula Complete Cleansing Oil
# 1               Matcha Hemp Hydrating Cleanser 120ml
# 2                   Low pH Good Morning Gel Cleanser
# 3                                     All Clean Balm
# 4  AHA-BHA-PHA 30days Miracle Acne Clear Body Cle...
#
#                             pr_type      product type  \
# 0    [Product Type,  Cleansing Oil]     Cleansing Oil
# 1    [Product Type,  Cleansing Gel]     Cleansing Gel
# 2    [Product Type,  Cleansing Gel]     Cleansing Gel
# 3   [Product Type,  Cleansing Balm]    Cleansing Balm
# 4  [Product Type,  Cleansing Water]   Cleansing Water
#
#                                              sk_type  \
# 0       [Skin Type,  Combination, Dry, Normal, Oily]
# 1       [Skin Type,  Combination, Dry, Normal, Oily]
# 2                      [Skin Type,  Oily, Sensitive]
# 3  [Skin Type,  Combination, Dry, Normal, Oily, S...
# 4       [Skin Type,  Combination, Dry, Normal, Oily]
#
#                                     skin type  \
# 0              Combination, Dry, Normal, Oily
# 1              Combination, Dry, Normal, Oily
# 2                             Oily, Sensitive
# 3   Combination, Dry, Normal, Oily, Sensitive
# 4              Combination, Dry, Normal, Oily
#
#                                           sk_concern  \
# 0    [Skin Concern,  Blackheads, Oil Control/ Pores]
# 1        [Skin Concern,  Acne, Anti-aging/ Wrinkles]
# 2  [Skin Concern,  Acne, Blackheads, Dryness/ Hyd...
# 3  [Skin Concern,  Acne, Blackheads, Oil Control/...
# 4         [Skin Concern,  Acne, Irritation/ Calming]
#
#                                         skin concern
# 0                     Blackheads, Oil Control/ Pores
# 1                         Acne, Anti-aging/ Wrinkles
# 2   Acne, Blackheads, Dryness/ Hydration, Irritat...
# 3               Acne, Blackheads, Oil Control/ Pores
# 4                          Acne, Irritation/ Calming

# %% [markdown]
# # 4. Droppear columnas no necesarias

# %%
df.drop(columns=['name', 'Unnamed: 0', 'Unnamed: 0.1', 'details', 'product name', 'pr_type', 'sk_type', 'sk_concern'], axis=1, inplace=True)

# %%
ordered_cols = ['brand', 'product', 'Step', 'product type', 'skin type', 'skin concern', 'ingredients', 'price', 'best-seller']
df = df[ordered_cols]

# %%
df
# Out:
#                  brand                                            product  \
# 0                iUNIK                   Calendula Complete Cleansing Oil
# 1                Krave               Matcha Hemp Hydrating Cleanser 120ml
# 2                COSRX                   Low pH Good Morning Gel Cleanser
# 3              heimish                                     All Clean Balm
# 4           SOME BY MI  AHA-BHA-PHA 30days Miracle Acne Clear Body Cle...
# ...                ...                                                ...
# 4381   NATURE REPUBLIC                              Pore Away Clear Toner
# 4382          The Saem                             Eco Energy Fresh Toner
# 4383          The Saem                             Eco Energy Fresh Toner
# 4384  NEOGEN Dermalogy                                  Pore Refine Toner
# 4385         VANT 36.5                                       AHA 5% Toner
#
#            Step      product type                                   skin type  \
# 0     cleansers     Cleansing Oil              Combination, Dry, Normal, Oily
# 1     cleansers     Cleansing Gel              Combination, Dry, Normal, Oily
# 2     cleansers     Cleansing Gel                             Oily, Sensitive
# 3     cleansers    Cleansing Balm   Combination, Dry, Normal, Oily, Sensitive
# 4     cleansers   Cleansing Water              Combination, Dry, Normal, Oily
# ...         ...               ...                                         ...
# 4381      toner      Toner & Mist              Combination, Dry, Normal, Oily
# 4382      toner      Toner & Mist              Combination, Dry, Normal, Oily
# 4383      toner      Toner & Mist              Combination, Dry, Normal, Oily
# 4384      toner      Toner & Mist   Combination, Dry, Normal, Oily, Sensitive
# 4385      toner      Toner & Mist              Combination, Dry, Normal, Oily
#
#                                            skin concern  \
# 0                        Blackheads, Oil Control/ Pores
# 1                            Acne, Anti-aging/ Wrinkles
# 2      Acne, Blackheads, Dryness/ Hydration, Irritat...
# 3                  Acne, Blackheads, Oil Control/ Pores
# 4                             Acne, Irritation/ Calming
# ...                                                 ...
# 4381            Dryness/ Hydration, Dullness / Radiance
# 4382             Dryness/ Hydration, Oil Control/ Pores
# 4383             Dryness/ Hydration, Oil Control/ Pores
# 4384             Dryness/ Hydration, Oil Control/ Pores
# 4385                                 Dryness/ Hydration
#
#                                             ingredients   price   best-seller
# 0                                                   NaN  15.19€  Best Sellers
# 1                                                   NaN  31.29€  Best Sellers
# 2     Water, Cocamidopropyl Betaine, Sodium Lauroyl ...   9.49€  Best Sellers
# 3     Ethylhexyl Palmitate, Cetyl Ethylhexanoate, PE...  14.89€  Best Sellers
# 4                                                   NaN  15.09€  Best Sellers
# ...                                                 ...     ...           ...
# 4381                                                NaN     NaN            no
# 4382                                                NaN     NaN            no
# 4383                                                NaN     NaN            no
# 4384                                                NaN  18.79€  Cruelty Free
# 4385                                                NaN     NaN            no
#
# [4386 rows x 9 columns]

# %%
df.to_csv('final.csv', index=False)

# %% [markdown]
# # 5. LIMPIAR DATOS

# %%
final = pd.read_csv('final.csv')

# %%
lst = dict(final.groupby("product").filter(lambda x: len(x) > 1)['product'].value_counts())

# %%
lst
# Out:
# {'Hada Labo': 36,
#  'Softymo': 8,
#  'Cleansing Foam': 7,
#  'DECORTE': 7,
#  'Curel': 7,
#  'Real Nature Hydrogel Mask': 7,
#  'Pressed Serum': 6,
#  'Senka': 5,
#  'Gatsby': 5,
#  'ELIXIR': 5,
#  'Ph 5.5 Jelly Mask': 5,
#  'Sunplay': 5,
#  'Natural Condition Cleansing Foam': 5,
#  'S Claa': 5,
#  'Golden Snail Intensive Essence': 4,
#  'The True Cream': 4,
#  '[]': 4,
#  'Healing Tea Garden Cleansing Foam': 4,
#  'SEKKISEI': 4,
#  'LITS Revival': 4,
#  'Fermentation Peptine Eye Care Cream': 4,
#  'Instantly Brewing Tea Bag Mask': 4,
#  'ALLIE': 4,
#  'Super Vegitoks Cleanser': 4,
#  'Daily Purifying Foam Cleansing': 4,
#  'UV Wise Brightening Multi Protector': 4,
#  'Anessa': 4,
#  'Extreme White Serum': 4,
#  'ULTIMUNE Power Infusing Concentrate': 4,
#  'Hydrogel Mask Pack': 4,
#  'Fresh Herb Cleansing Foam': 4,
#  'MEISHOKU': 4,
#  'Black Rice Hyaluronic Toner': 4,
#  'Power Spot Cream': 4,
#  'Clean It Zero Cleansing Balm': 4,
#  'Bio': 3,
#  'Skin Peel': 3,
#  'Baking Powder BB Deep Cleansing Foam': 3,
#  '4SP Cherry Blossom Amino Fresh Fluid': 3,
#  'TS Propolis Serum': 3,
#  'Cream Cleansing Foam': 3,
#  'Herbal Soap': 3,
#  'Radian-C Cream': 3,
#  'Grace One': 3,
#  'Essential Power Skin Refiner Moisture': 3,
#  'Biore': 3,
#  'Micro Micellar Deep Cleansing Foam': 3,
#  'Acne Control Medicated': 3,
#  'Glacial Clay Foam': 3,
#  'IPSA': 3,
#  'Granactive Retinoid Emulsion 2% + GABA Serum': 3,
#  'Nourishing cream': 3,
#  'Real Fresh Foam': 3,
#  'Gold Helichrysum Repair Essence Lotion': 3,
#  'Farmer Piggy Jojoba Oil 100%': 3,
#  'Ampoule Mist': 3,
#  'Madeca Micro Sartoc Serum': 3,
#  'CLÉ DE PEAU BEAUTÉ': 3,
#  'Za': 3,
#  'Herb Solution Toner': 3,
#  'Uno': 3,
#  'Pressed Serum Mini': 3,
#  'Daily Perfume Foam Cleanser': 3,
#  'Super White 377 VC Essence': 3,
#  'Power 10 Formula CO Effector': 3,
#  'Sunplay Sunblock': 3,
#  'Moisture Cream': 3,
#  'Natural Condition Cleansing Oil': 3,
#  'Hydramax Serum': 3,
#  'Derma Plan Green Control Serum': 3,
#  'ONE BY KOSE': 3,
#  'Agas ACue Serum': 3,
#  'Premium Tone-Up Cream': 2,
#  'Mugwort Mask': 2,
#  'Refresh AHA BHA Vitamin C Daily Toner (ABC Daily Toner)': 2,
#  'Honest Cleansing Foam': 2,
#  '7 Days Secret Centella Cica Toner': 2,
#  'Sofina': 2,
#  'SunCut': 2,
#  'Marine Luminous Pearl Hydrogel Mask Pearl': 2,
#  'Bloomstay Vitalizing Water': 2,
#  'Natural Perfection Natural Perfection Double Shield Sun Stick (2020 new)': 2,
#  'Organic Jojoba Oil': 2,
#  'Peptide No-Sebum Balancing Toner': 2,
#  'The Natural Avocado Cleansing Foam': 2,
#  'Concentrated Ginseng Renewing Cream EX': 2,
#  'Pure Root': 2,
#  'White Truffle First Spray Serum': 2,
#  'Whitening Cream': 2,
#  'The Chok Chok Green Tea Watery Cream': 2,
#  'Natuer Be': 2,
#  'Red Rice Essential Skin Softener': 2,
#  'Propolis Vitamin Synergy Serum': 2,
#  'Patting Splash Mask': 2,
#  'Ageless Real Eye Cream For Face': 2,
#  'Hydra G6 Essence Toner': 2,
#  "Men's Biore Facial Wash": 2,
#  'Cicaloe Relief Sun Milk': 2,
#  'Vital Treatment': 2,
#  'Moistfull Collagen Cream': 2,
#  'Green Tea Seed Serum': 2,
#  'Blueberry Hydrating Cream': 2,
#  'Kokutousei Premium': 2,
#  'The Chok Chok Green Tea Cleansing Water': 2,
#  'Perfume Soap': 2,
#  'The True Cream Aqua Bomb': 2,
#  'Cellup Ph Cure Foam Cleanser': 2,
#  'Eye Cream & Hydrogel Mask': 2,
#  'VITAL-PERFECTION Wrinklelift Cream': 2,
#  'Skin Aqua UV Super Moisture Milk SPF50+ PA++++': 2,
#  'Deep Green Tea Toner': 2,
#  'Full Fit Propolis Synergy Toner': 2,
#  'Dermalogy Real Ferment Micro Essence': 2,
#  "Men's Biore Double Scrub Facial Foam": 2,
#  'Facial Yogurt Cleansing Foam': 2,
#  'Cellus Revive Essence Toner': 2,
#  'Real Art Cleansing Oil Moisture': 2,
#  '130ml': 2,
#  'The Natural Olive Cleansing Foam': 2,
#  'Madeca Cream Active Skin Formula': 2,
#  'Airy Skin Spa Cleanser Mild Acidic Ph': 2,
#  'Jeju Orchid Enriched Cream': 2,
#  'Cream Skin Refiner': 2,
#  'Black Bamboo Mist': 2,
#  'Power 10 Formula Mist': 2,
#  'Dr.Jart +': 2,
#  'Essential Balancing Water EX': 2,
#  'Gongjinhyang Intensive Nutritive Cream': 2,
#  'Coix Lacryma-Jobi Ma-Yuen Seed Extract': 2,
#  'R.N.A.Power Airy Milky Lotion': 2,
#  'Power 10 Formula GF Effector': 2,
#  'Monster Micellar Deep Cleansing Water Mild': 2,
#  'The Natural Lemon Cleansing Foam': 2,
#  'Gold Collagen One Day Kit': 2,
#  'Cellup Micro Foam Cleanser': 2,
#  'Derma Formula Green Tea Probiotics Cream': 2,
#  'Alpine Berry Watery Cream': 2,
#  'Falling into the rose Mist': 2,
#  'Clean it Zero Cleansing Balm': 2,
#  'Intensive Hydrating Serum With Hyaluronic Acid': 2,
#  '24K Gold Caviar Repair Vital Cream': 2,
#  'Amazon Belief Protection Andirova Sunblock': 2,
#  'Green Vita C Soothing Toner': 2,
#  'Nature Be': 2,
#  'Green Grape Pore Control Cream': 2,
#  'Water Wash Balm': 2,
#  'Cellus Mist Toner': 2,
#  'Green Tea Foam Cleanser': 2,
#  'Deep Clean Clay Foam': 2,
#  'Rice Powder Polish': 2,
#  'Silky Bright Enzyme Powder Facial Wash': 2,
#  'First Treatment Essence': 2,
#  'Houttuynia Cordata Extract': 2,
#  'Eco Energy Fresh Toner': 2,
#  'Hyaluronic Toner': 2,
#  'Wonder Pore Freshener': 2,
#  'Black Rice Facial Oil': 2,
#  'Skin Conditioner Essential': 2,
#  'Green Vita C Water Gel Cream': 2,
#  'Obagi': 2,
#  'Pure Cleansing Oil': 2,
#  'MANGO SEED ADVANCED CREAMY CLEANSING FOAM': 2,
#  'Hyaluronic Serum': 2,
#  'Snail Bee High Content Steam Cream': 2,
#  'It Is Real Gel Mist': 2,
#  'Clean It Zero Cleansing Balm Original (Care Bears Edition)': 2,
#  'Hyaluronic Acid Moisturizing Liquid': 2,
#  'Baking Powder Pore Cleansing Foam': 2,
#  'Concentrated Ginseng Renewing Serum': 2,
#  'Atorrege AD+': 2,
#  'Brassica Oleracea Italica Extract': 2,
#  'Numero 10 Essence': 2,
#  'Scrub Mask Sweet Therapy': 2,
#  'The Seed Real Collagen Mask': 2,
#  'CEQ Anti-oxidant Serum': 2,
#  'Alpine Berry Watery Soothing Gel Cream': 2,
#  'Airy Skin Spa Cleanser 30 Days Mild Acidic Ph': 2,
#  'Black Rice Hyaluronic Cream': 2,
#  'Centella Asiatica Extract': 2,
#  'Facial Treatment Clear Lotion': 2,
#  'Clear Skin 8% AHA Essence': 2,
#  'Miracle Moisture Essence': 2,
#  'Hyaluronic Cream': 2,
#  'Power 10 Formula VC Effector': 2,
#  'Soon Jung Hydro Barrier Cream': 2,
#  'Olive Real Oil Mist EX': 2,
#  'Premium Sun Protection Creme SPF50+ PA+++': 2,
#  'Snow White Shining Whitening Cream': 2,
#  'Pomegranate Nutri-Moisturizing Cream': 2,
#  'Gongjinhyang Essential Moisturizing Balancer': 2,
#  'Hyaluronic Acid Essence': 2,
#  'Avocado Relief Cream': 2,
#  'Honey Mask': 2,
#  'Mild Whip Pore Cleansing Foam': 2,
#  'UNO': 2,
#  'Green Tea Mist': 2,
#  'Snail Bee High Content Skin': 2,
#  'Bloomstay Vitalizing Cream': 2,
#  'OXY Face Wash': 2,
#  '21;STAY A-Thera Peeling Stick': 2,
#  'Keana': 2,
#  'Aqua Soothing Gel Cream': 2,
#  'Stress Shooter': 2,
#  'Herb Day 365 Master Blending Foaming Pump Cleanser': 2,
#  'Airgel Bounce Up Mask': 2,
#  'Cera Routine Essential Toner': 2,
#  'Day Shield Perfect Sun Black': 2,
#  'Artemisia Capillaris Extract': 2,
#  'Concentrated Ginseng Renewing Water': 2,
#  'Pore Cleaning Hydrogel Mask': 2,
#  'Bubble Cleanser': 2,
#  'Dr.Troub Skin Returning Functional Hydrogel Mask': 2,
#  'Brightening Peeling Gel': 2,
#  'Truecare Panthenol 10 Moisture Skin': 2,
#  'Mandelic Acid Essence 5%': 2,
#  'Hydrium Watery Toner': 2,
#  'Super Aqua Max Soft Peeling Gel': 2,
#  'Snail Repairing Cream': 2,
#  'Cellus Deep Moisture Cream': 2,
#  'Timetreasure Extra Creamy Cleansing Foam': 2,
#  'Citrus Brightening Cream': 2,
#  'Aqua Shower Look Hydrogel Mask': 2,
#  'Green Tea Balancing Skin EX': 2,
#  'Prime Advancer Skin Softener': 2,
#  'AHA-BHA-PHA 30 Days Miracle Toner': 2,
#  'Cream Skin Quick Skin Pack': 2,
#  'Deep Clean Cleansing Oil': 2,
#  'Preange': 2,
#  'Organience Hydro Gel Mask': 2,
#  'Moisture Mild Lotion': 2,
#  'Tea Tree Toner': 2,
#  'Deep Clear Bright Calming Peeling Gel': 2,
#  'Acnes': 2,
#  'Time Rewind Real Eye Cream For Face': 2,
#  'NKB Zero': 2}

# %%
cleansers = pd.read_csv('clean_data/cleansers.csv')

# %%
final
# Out:
#                  brand                                            product  \
# 0                iUNIK                   Calendula Complete Cleansing Oil
# 1                Krave               Matcha Hemp Hydrating Cleanser 120ml
# 2                COSRX                   Low pH Good Morning Gel Cleanser
# 3              heimish                                     All Clean Balm
# 4           SOME BY MI  AHA-BHA-PHA 30days Miracle Acne Clear Body Cle...
# ...                ...                                                ...
# 4381   NATURE REPUBLIC                              Pore Away Clear Toner
# 4382          The Saem                             Eco Energy Fresh Toner
# 4383          The Saem                             Eco Energy Fresh Toner
# 4384  NEOGEN Dermalogy                                  Pore Refine Toner
# 4385         VANT 36.5                                       AHA 5% Toner
#
#            Step      product type                                   skin type  \
# 0     cleansers     Cleansing Oil              Combination, Dry, Normal, Oily
# 1     cleansers     Cleansing Gel              Combination, Dry, Normal, Oily
# 2     cleansers     Cleansing Gel                             Oily, Sensitive
# 3     cleansers    Cleansing Balm   Combination, Dry, Normal, Oily, Sensitive
# 4     cleansers   Cleansing Water              Combination, Dry, Normal, Oily
# ...         ...               ...                                         ...
# 4381      toner      Toner & Mist              Combination, Dry, Normal, Oily
# 4382      toner      Toner & Mist              Combination, Dry, Normal, Oily
# 4383      toner      Toner & Mist              Combination, Dry, Normal, Oily
# 4384      toner      Toner & Mist   Combination, Dry, Normal, Oily, Sensitive
# 4385      toner      Toner & Mist              Combination, Dry, Normal, Oily
#
#                                            skin concern  \
# 0                        Blackheads, Oil Control/ Pores
# 1                            Acne, Anti-aging/ Wrinkles
# 2      Acne, Blackheads, Dryness/ Hydration, Irritat...
# 3                  Acne, Blackheads, Oil Control/ Pores
# 4                             Acne, Irritation/ Calming
# ...                                                 ...
# 4381            Dryness/ Hydration, Dullness / Radiance
# 4382             Dryness/ Hydration, Oil Control/ Pores
# 4383             Dryness/ Hydration, Oil Control/ Pores
# 4384             Dryness/ Hydration, Oil Control/ Pores
# 4385                                 Dryness/ Hydration
#
#                                             ingredients   price   best-seller
# 0                                                   NaN  15.19€  Best Sellers
# 1                                                   NaN  31.29€  Best Sellers
# 2     Water, Cocamidopropyl Betaine, Sodium Lauroyl ...   9.49€  Best Sellers
# 3     Ethylhexyl Palmitate, Cetyl Ethylhexanoate, PE...  14.89€  Best Sellers
# 4                                                   NaN  15.09€  Best Sellers
# ...                                                 ...     ...           ...
# 4381                                                NaN     NaN            no
# 4382                                                NaN     NaN            no
# 4383                                                NaN     NaN            no
# 4384                                                NaN  18.79€  Cruelty Free
# 4385                                                NaN     NaN            no
#
# [4386 rows x 9 columns]
