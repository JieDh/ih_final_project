# %%
import pandas as pd

# %%
df = pd.read_csv('data/eyecreams.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 382 entries, 0 to 381
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   382 non-null    int64
#  1   name         382 non-null    object
#  2   details      382 non-null    object
#  3   ingredients  382 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 12.1+ KB

# %%
df
# Out:
#      Unnamed: 0                                               name  \
# 0             0                     [LANEIGE ,  Lip Sleeping Mask]
# 1             1  [PURITO ,  Centella Green Level Eye Cream ,  3...
# 2             2      [iUNIK ,  Propolis Vitamin Eye Cream ,  30ml]
# 3             3                 [Benton ,  Fermentation Eye Cream]
# 4             4                     [Etude House ,  My Lash Serum]
# ..          ...                                                ...
# 377         377                 [Mongdies ,  Lip Treatment ,  15g]
# 378         378      [IOPE ,  Lip Nutri, Volume Serum Pure ,  15g]
# 379         379         [LITS ,  LITS Revival ,  Line Zero ,  12g]
# 380         380  [ISOI ,  Bulgarian Intensive Age, Control Eye ...
# 381         381     [OGI ,  Water Bomb Moisture Eye Cream ,  20ml]
#
#                                                details  \
# 0    Product Type: Lip Mask\n\n\nProduct Unit: 20g\...
# 1    Cruelty Free: Yes\n\n\nProduct Type: Eye Cream...
# 2    Skin Concern: Anti-aging/ Wrinkles, Dark Circl...
# 3    Cruelty Free: Yes\n\n\nProduct Type: Eye Cream...
# 4    Product Type: Eyelash Essence\n\n\nSkin Type: ...
# ..                                                 ...
# 377  Product Type: Lip Mask\n\n\nSkin Concern: Irri...
# 378  Skin Concern: Anti-aging/ Wrinkles, Dryness/ H...
# 379  Product Type: Eye Cream\n\n\nSkin Concern: Ant...
# 380  Product Type: Eye Cream\n\n\nSkin Concern: Ant...
# 381  Product Type: Eye Cream\n\n\nSkin Concern: Ant...
#
#                                            ingredients
# 0    Diisostearyl Malate, Hydrogenated Polyisobuten...
# 1    Centella Asiatica Extract, Water, Hydrogenated...
# 2                                                   []
# 3    Galactomyces Ferment Filtrate, Aqua (Water), B...
# 4    Water, Butylene Glycol, Alcohol, Glycerin, Alo...
# ..                                                 ...
# 377  Caprylic/Capric Triglyceride, Polybutene, Bis-...
# 378                                                 []
# 379  Water, Dimethicone, Cyclopentasiloxane, Silica...
# 380  Water, Glycerin, Octyldodecyl Myristate, Cetyl...
# 381  Water, Glycerin, Dipropylene Glycol, Caprylic/...
#
# [382 rows x 4 columns]

# %% [markdown]
# # 1. Separar marca y producto

# %%
df['name'] = df['name'].apply(lambda x: x.split(' - '))

# %%
df['brand'] = df['name'].apply(lambda x: x[0])
df['product name'] = df['name'].apply(lambda x: x[1:])

# %%
df
#el nombre del producto contiene más info de la necesaria, corregir
# Out:
#      Unnamed: 0                                               name  \
# 0             0                       [LANEIGE, Lip Sleeping Mask]
# 1             1     [PURITO, Centella Green Level Eye Cream, 30ml]
# 2             2          [iUNIK, Propolis Vitamin Eye Cream, 30ml]
# 3             3                   [Benton, Fermentation Eye Cream]
# 4             4                       [Etude House, My Lash Serum]
# ..          ...                                                ...
# 377         377                     [Mongdies, Lip Treatment, 15g]
# 378         378           [IOPE, Lip Nutri-Volume Serum Pure, 15g]
# 379         379               [LITS, LITS Revival, Line Zero, 12g]
# 380         380  [ISOI, Bulgarian Intensive Age-Control Eye Cre...
# 381         381         [OGI, Water Bomb Moisture Eye Cream, 20ml]
#
#                                                details  \
# 0    [Product Type: Lip Mask, Product Unit: 20g, Sk...
# 1    [Cruelty Free: Yes, Product Type: Eye Cream, S...
# 2    [Skin Concern: Anti-aging/ Wrinkles, Dark Circ...
# 3    [Cruelty Free: Yes, Product Type: Eye Cream, P...
# 4    [Product Type: Eyelash Essence, Skin Type: Com...
# ..                                                 ...
# 377  [Product Type: Lip Mask, Skin Concern: Irritat...
# 378  [Skin Concern: Anti-aging/ Wrinkles, Dryness/ ...
# 379  [Product Type: Eye Cream, Skin Concern: Anti-a...
# 380  [Product Type: Eye Cream, Skin Concern: Anti-a...
# 381  [Product Type: Eye Cream, Skin Concern: Anti-a...
#
#                                            ingredients        brand  \
# 0    Diisostearyl Malate, Hydrogenated Polyisobuten...      LANEIGE
# 1    Centella Asiatica Extract, Water, Hydrogenated...       PURITO
# 2                                                   []        iUNIK
# 3    Galactomyces Ferment Filtrate, Aqua (Water), B...       Benton
# 4    Water, Butylene Glycol, Alcohol, Glycerin, Alo...  Etude House
# ..                                                 ...          ...
# 377  Caprylic/Capric Triglyceride, Polybutene, Bis-...     Mongdies
# 378                                                 []         IOPE
# 379  Water, Dimethicone, Cyclopentasiloxane, Silica...         LITS
# 380  Water, Glycerin, Octyldodecyl Myristate, Cetyl...         ISOI
# 381  Water, Glycerin, Dipropylene Glycol, Caprylic/...          OGI
#
#                                           product name
# 0                                  [Lip Sleeping Mask]
# 1               [Centella Green Level Eye Cream, 30ml]
# 2                   [Propolis Vitamin Eye Cream, 30ml]
# 3                             [Fermentation Eye Cream]
# 4                                      [My Lash Serum]
# ..                                                 ...
# 377                               [Lip Treatment, 15g]
# 378                 [Lip Nutri-Volume Serum Pure, 15g]
# 379                     [LITS Revival, Line Zero, 12g]
# 380  [Bulgarian Intensive Age-Control Eye Cream, 20ml]
# 381              [Water Bomb Moisture Eye Cream, 20ml]
#
# [382 rows x 6 columns]

# %%
df['details'] = df['details'].apply(lambda x: x.split('\n\n\n'))

# %%
l1 = df['details'][0]

# %%
d1=dict(enumerate(l1))

# %%
d1
# Out:
# {0: 'Product Type: Lip Mask',
#  1: 'Product Unit: 20g',
#  2: 'Skin Type: Combination, Dry, Normal, Oily, Sensitive'}

# %%
prdf = df['details'].apply(lambda x: dict(enumerate(x)))

# %%
prdf.apply(pd.Series)
# Out:
#                                                      0  \
# 0                               Product Type: Lip Mask
# 1                                    Cruelty Free: Yes
# 2    Skin Concern: Anti-aging/ Wrinkles, Dark Circl...
# 3                                    Cruelty Free: Yes
# 4                        Product Type: Eyelash Essence
# ..                                                 ...
# 377                             Product Type: Lip Mask
# 378  Skin Concern: Anti-aging/ Wrinkles, Dryness/ H...
# 379                            Product Type: Eye Cream
# 380                            Product Type: Eye Cream
# 381                            Product Type: Eye Cream
#
#                                                      1  \
# 0                                    Product Unit: 20g
# 1                              Product Type: Eye Cream
# 2            Skin Type: Combination, Dry, Normal, Oily
# 3                              Product Type: Eye Cream
# 4            Skin Type: Combination, Dry, Normal, Oily
# ..                                                 ...
# 377                  Skin Concern: Irritation/ Calming
# 378          Skin Type: Combination, Dry, Normal, Oily
# 379  Skin Concern: Anti-aging/ Wrinkles, Dryness/ H...
# 380  Skin Concern: Anti-aging/ Wrinkles, Dryness/ H...
# 381  Skin Concern: Anti-aging/ Wrinkles, Dark Circl...
#
#                                                      2  \
# 0    Skin Type: Combination, Dry, Normal, Oily, Sen...
# 1    Skin Concern: Anti-aging/ Wrinkles, Dryness/ H...
# 2                                                  NaN
# 3                                    Product Unit: 30g
# 4                                                  NaN
# ..                                                 ...
# 377  Skin Type: Combination, Dry, Normal, Oily, Sen...
# 378                                                NaN
# 379          Skin Type: Combination, Dry, Normal, Oily
# 380          Skin Type: Combination, Dry, Normal, Oily
# 381          Skin Type: Combination, Dry, Normal, Oily
#
#                                                      3  \
# 0                                                  NaN
# 1    Skin Type: Combination, Dry, Normal, Oily, Sen...
# 2                                                  NaN
# 3    Skin Concern: Anti-aging/ Wrinkles, Dryness/ H...
# 4                                                  NaN
# ..                                                 ...
# 377                                                NaN
# 378                                                NaN
# 379                                                NaN
# 380                                                NaN
# 381                                                NaN
#
#                                                      4
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    Skin Type: Combination, Dry, Normal, Oily, Sen...
# 4                                                  NaN
# ..                                                 ...
# 377                                                NaN
# 378                                                NaN
# 379                                                NaN
# 380                                                NaN
# 381                                                NaN
#
# [382 rows x 5 columns]
