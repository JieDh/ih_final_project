# %%
import pandas as pd

# %%
df = pd.read_csv('data/sample.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   36 non-null     int64
#  1   name         36 non-null     object
#  2   details      36 non-null     object
#  3   ingredients  36 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 1.2+ KB

# %%
df
# Out:
#     Unnamed: 0                                               name  \
# 0            0   iUNIK - Calendula Complete Cleansing Oil - 200ml
# 1            1       Krave - Matcha Hemp Hydrating Cleanser 120ml
# 2            2   COSRX - Low pH Good Morning Gel Cleanser - 150ml
# 3            3                           heimish - All Clean Balm
# 4            4  SOME BY MI - AHA-BHA-PHA 30days Miracle Acne C...
# 5            5  Isntree - Micellar Washing Cleansing Water - 3...
# 6            6            BEAUTY OF JOSEON - Cleansing Balm - 80g
# 7            7  Haruharu WONDER - Black Rice Moisture Deep Cle...
# 8            8     iUNIK - Centella Bubble Cleansing Foam - 150ml
# 9            9             heimish - All Clean Green Foam - 150ml
# 10          10  SOME BY MI - Bye Bye Blackhead 30days Miracle ...
# 11          11  Farm Stay - Char-Coal Pure Cleansing Foam - 180ml
# 12          12   iUNIK - Calendula Complete Cleansing Oil - 200ml
# ...

# %%
separated_brand_info = df['name'].str.split('- ', expand=True)

# %%
cleansers_df = pd.concat([df, separated_brand_info], axis=1)

# %%
separated_details = df['details'].str.split('\n\n\n', expand=True)

# %%
separated_details.columns = ['product type', 'skin concern', 'skin type', 'other', 'other2']

# %%
separated_details['other'].unique()
# Out:
# array([None, 'Skin Type: Oily, Sensitive',
#        'Skin Concern: Acne, Blackheads, Oil Control/ Pores',
#        'Skin Concern: Dryness/ Hydration, Dullness / Radiance, Oil Control/ Pores',
#        'Skin Concern: Dryness/ Hydration, Dullness / Radiance',
#        'Skin Type: Combination, Dry, Normal, Oily'], dtype=object)

# %%
cols = list(cleansers_df.columns.values)
cols
# Out:
# ['Unnamed: 0', 'name', 'details', 'ingredients', 0, 1, 2]

# %%
# cleansers_df = cleansers_df[['Unnamed: 0', 'name', 'brand', 'product', 0, 1, 2, 3, 4, 'details', 'ingredients']]

# %%
#drop columns: 'brand, product, 4'
